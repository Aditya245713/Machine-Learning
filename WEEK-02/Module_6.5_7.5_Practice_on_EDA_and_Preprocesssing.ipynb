# %% [markdown]
# # Moduel 6.5: Practice Notebook on Module 06 – Exploratory Data Analysis (EDA)
#
# In this practice notebook, you will choose **one dataset** from the list below and repeat the full EDA steps you learned in Module 06.
#
# ## Dataset Options (Choose One)
#
# 1. E-Commerce Fraud Detection Dataset
#    https://www.kaggle.com/datasets/umuttuygurr/e-commerce-fraud-detection-dataset
#
# 2. BreastDataset
#    https://www.kaggle.com/datasets/khansaafreen/breastdataset
#
# 3. Titanic Dataset
#    https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# 4. Loan Approval Dataset
#    https://www.kaggle.com/datasets/anishdevedward/loan-approval-dataset
#
# 5. Diabetes Health Indicators Dataset
#    https://www.kaggle.com/datasets/mohankrishnathalla/diabetes-health-indicators-dataset
#
# 6. Alzheimer’s Disease Dataset
#    https://www.kaggle.com/datasets/rabieelkharoua/alzheimers-disease-dataset
#
# 7. Students Performance Dataset
#    https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset
#
# 8. Cancer Data
#    https://www.kaggle.com/datasets/erdemtaha/cancer-data
#
# 9. Mushroom Classification
#    https://www.kaggle.com/datasets/uciml/mushroom-classification
#
# 10. Rain in Australia
#    https://www.kaggle.com/datasets/jsphyg/weather-dataset-rattle-package
#
# ---

# %% [markdown]
# ## Section 1 — Dataset Selection and Brief Description
#
# **Instructions:**
#
# - Write the name of the dataset you selected.
# - Copy a brief description from the Kaggle page (2–3 lines).
# - Mention your **target column** (if applicable).

# %% [markdown]
# ### Student Notes and Observations
#
# 1. Students Performance Dataset
# 2. This dataset contains comprehensive information on 2,392 high school students, detailing their demographics, study habits, parental involvement, extracurricular activities, and academic performance. The target variable, GradeClass, classifies students' grades into distinct categories, providing a robust dataset for educational research, predictive modeling, and statistical analysis.
# 3. Grade Class

# %% [markdown]
# ## Section 2 — Upload the Dataset and Load into Pandas
#
# You will now upload your chosen CSV file and load it into a Pandas DataFrame.

# %%
# TODO:
# 1. Upload your chosen CSV file using files.upload()
# 2. Load it into a DataFrame using pd.read_csv()
# 3. Display the first 5 rows using df.head()

#Import Necessary Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("default")
sns.set(font_scale=1.1)

#from google.colab import files

# Upload Student_performance_data _.csv from your computer
#uploaded = files.upload()

# The Kaggle file is named "Student_performance_data _.csv"
df = pd.read_csv("Student_performance_data _.csv")

df.head(10)
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
# 5       1006   18       0          0                  1         8.191219
# 6       1007   15       0          1                  1        15.601680
# 7       1008   15       1          1                  4        15.424496
# 8       1009   17       0          0                  0         4.562008
# 9       1010   16       1          0                  1        18.444466
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
# 5         0         0                1                1       0      0
# 6        10         0                3                0       1      0
# 7        22         1                1                1       0      0
# 8         1         0                2                0       1      0
# 9         0         0                3                1       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0
# 5             0  3.084184         1.0
# 6             0  2.748237         2.0
# 7             0  1.360143         4.0
# 8             1  2.896819         2.0
# 9             0  3.573474         0.0

# %% [markdown]
# ### Student Notes and Observations
#
# Lotta Caucasians, Disparity in Tutoring

# %% [markdown]
# ## Section 3 — Basic Dataset Information (Shape, Info, Describe)
#
# Now inspect the basic structure of the dataset.

# %%
# TODO:
# 1. Print the shape of the dataset (rows, columns)
# 2. Display df.info() to inspect data types and missing counts
# 3. Show df.describe().T for numeric statistics

# Basic info about rows, columns, and data types
print("Shape: ", df.shape)
# Out:
# Shape:  (2392, 15)

# %%
print("Info: ")
df.info()
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
# Quick descriptive statistics for numeric columns
df.describe().T
# Out:
#                     count         mean         std          min          25%  \
# StudentID          2392.0  2196.500000  690.655244  1001.000000  1598.750000
# Age                2392.0    16.468645    1.123798    15.000000    15.000000
# Gender             2392.0     0.510870    0.499986     0.000000     0.000000
# Ethnicity          2392.0     0.877508    1.028476     0.000000     0.000000
# ParentalEducation  2392.0     1.746237    1.000411     0.000000     1.000000
# StudyTimeWeekly    2392.0     9.771992    5.652774     0.001057     5.043079
# Absences           2392.0    14.541388    8.467417     0.000000     7.000000
# Tutoring           2392.0     0.301421    0.458971     0.000000     0.000000
# ParentalSupport    2392.0     2.122074    1.122813     0.000000     1.000000
# Extracurricular    2392.0     0.383361    0.486307     0.000000     0.000000
# Sports             2392.0     0.303512    0.459870     0.000000     0.000000
# Music              2392.0     0.196906    0.397744     0.000000     0.000000
# Volunteering       2392.0     0.157191    0.364057     0.000000     0.000000
# GPA                2392.0     1.906186    0.915156     0.000000     1.174803
# GradeClass         2392.0     2.983696    1.233908     0.000000     2.000000
#
#                            50%          75%          max
# StudentID          2196.500000  2794.250000  3392.000000
# Age                  16.000000    17.000000    18.000000
# Gender                1.000000     1.000000     1.000000
# Ethnicity             0.000000     2.000000     3.000000
# ParentalEducation     2.000000     2.000000     4.000000
# StudyTimeWeekly       9.705363    14.408410    19.978094
# Absences             15.000000    22.000000    29.000000
# Tutoring              0.000000     1.000000     1.000000
# ParentalSupport       2.000000     3.000000     4.000000
# Extracurricular       0.000000     1.000000     1.000000
# Sports                0.000000     1.000000     1.000000
# Music                 0.000000     0.000000     1.000000
# Volunteering          0.000000     0.000000     1.000000
# GPA                   1.893393     2.622216     4.000000
# GradeClass            4.000000     4.000000     4.000000

# %% [markdown]
# ### Student Notes and Observations
#
# 15 Columns, Nothing too suspicious

# %% [markdown]
# ## Section 4 — Identify Target Column and Feature Types
#
# Separate the target and features into numeric and categorical groups.

# %%
# TODO:
# 1. Identify your target column name
# 2. Create a list of numeric feature columns
# 3. Create a list of categorical feature columns
# 4. Print all three

target_col = "GradeClass"

numeric_cols = ["Age", "StudyTimeWeekly",
                "Absences", "GPA"]

categorical_cols = ["Gender", "Ethnicity", "ParentalEducation",
                    "Tutoring", "ParentalSupport", "Extracurricular", "Sports", "Music", "Volunteering"]

print("Target:", target_col)
print("Numeric columns:", numeric_cols)
print("Categorical columns:", categorical_cols)
# Out:
# Target: GradeClass
# Numeric columns: ['Age', 'StudyTimeWeekly', 'Absences', 'GPA']
# Categorical columns: ['Gender', 'Ethnicity', 'ParentalEducation', 'Tutoring', 'ParentalSupport', 'Extracurricular', 'Sports', 'Music', 'Volunteering']

# %% [markdown]
# ### Student Notes and Observations
#
# Already Answered

# %% [markdown]
# ## Section 5 — Missing Values and Basic Quality Checks
#
# Check for missing values and basic sanity of value ranges.

# %%
# TODO:
# 1. Check missing values using df.isna().sum()
# 2. Print min, max, mean, and median for numeric columns using .agg()
# 3. For each categorical column, print unique values using df[col].unique()

# Check missing values count per column
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
# Look at some basic value ranges
df[numeric_cols].agg(["min", "max", "mean","median"]).T
# Out:
#                        min        max       mean     median
# Age              15.000000  18.000000  16.468645  16.000000
# StudyTimeWeekly   0.001057  19.978094   9.771992   9.705363
# Absences          0.000000  29.000000  14.541388  15.000000
# GPA               0.000000   4.000000   1.906186   1.893393

# %%
for c in categorical_cols:
  print(c, df[c].unique())
# Out:
# Gender [1 0]
# Ethnicity [0 2 1 3]
# ParentalEducation [2 1 3 4 0]
# Tutoring [1 0]
# ParentalSupport [2 1 3 4 0]
# Extracurricular [0 1]
# Sports [0 1]
# Music [1 0]
# Volunteering [0 1]

# %% [markdown]
# ### Student Notes and Observations
#
# No missing values. Nothing fishy.

# %% [markdown]
# ## Section 6 — Distributions: Histograms and Boxplots for Numeric Features
#
# Visualize numeric feature distributions and look for skewness or outliers.

# %%
# TODO:
# 1. Plot histograms for numeric features
# 2. Plot boxplots for numeric features to detect outliers

# Histograms for numeric features
df[numeric_cols].hist(bins=20, figsize=(12,8))
plt.suptitle("Histrograms of Numerical Features", fontsize = 14)
plt.tight_layout()
plt.show()

# %%
# Boxplots to get a sense of spread and possible outliers
plt.figure(figsize=(12,8))
df[numeric_cols].boxplot()
plt.title("Boxplot of Numerical Features")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Student Notes and Observations
#
# None look skewed. No outliers found.

# %% [markdown]
# ## Section 7 — Target Distribution and Class Imbalance
#
# Understand how balanced or imbalanced your target classes are.

# %%
# TODO:
# 1. Create a countplot of the target column
# 2. Show value counts and normalized proportions for the target

#Target Distribution and Class Imbalance
plt.figure(figsize=(5,4))
sns.countplot(x=df[target_col])
plt.title("GradeClass Distribution")
plt.xlabel("GradeClass (0 = A, 1 = B, 2 = C, 3 = D, 4 = F)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
df[target_col].value_counts(normalize=True)
# Out:
# GradeClass
# 4.0    0.506271
# 3.0    0.173077
# 2.0    0.163462
# 1.0    0.112458
# 0.0    0.044732
# Name: proportion, dtype: float64

# %% [markdown]
# ### Student Notes and Observations
#
# Heavily imbalanced.

# %% [markdown]
# ## Section 8 — Categorical Feature Exploration
#
# Look at distributions for each categorical feature.

# %%
# TODO:
# For each categorical column:
# 1. Plot a bar chart of value_counts()
# 2. Observe category balance and potential issues

#Categorical Feature Exploration
for c in categorical_cols:
  plt.figure(figsize=(5,4))
  df[c].value_counts().plot(kind="bar")
  plt.title(f"Value counts for {c}")
  plt.ylabel("Count")
  plt.tight_layout()
  plt.show()

# %% [markdown]
# ### Student Notes and Observations
#
# The ECA ones could be merged as they are few with 1s individually.

# %% [markdown]
# ## Section 9 — Numeric Features versus Target (Boxplots)
#
# Compare numeric feature distributions across different target classes.

# %%
# TODO:
# For each numeric feature:
# 1. Plot a boxplot with the feature on y axis and target on x axis
# 2. Compare distributions for each target class

# Boxplots of numeric features split by HeartDisease
plt.figure(figsize=(12,8))
for i, col in enumerate(numeric_cols,1):
  plt.subplot(2,2,i)
  sns.boxplot(x=df[target_col], y = df[col])
  plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Student Notes and Observations
#
# GPA, Absences, StudyTimeWeekly.

# %% [markdown]
# ## Section 10 — Pairplot and Correlation Analysis
#
# Explore relationships between features and correlations.

# %%
# TODO:
# 1. Create a pairplot with selected numeric features plus the target
# 2. Generate a correlation matrix for numeric features and target
# 3. Visualize the matrix with a heatmap
# 4. Sort correlations with the target column

#Pairplot for a Subset of Features
sns.pairplot(df[["Age","Absences","GPA", "StudyTimeWeekly", "GradeClass"]],hue="GradeClass", diag_kind="hist")
plt.show()

# %%
#Correlation Matrix and Heatmap
corr_matrix = df[numeric_cols + [target_col]].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm",fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap for Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Student Notes and Observations
#
# GPA and Absences.

# %% [markdown]
# ## Section 11 — Categorical Features versus Target (Crosstab and Stacked Bar Plot)
#
# Examine how target proportions change across categories.

# %%
# TODO:
# For each categorical feature:
# 1. Create a crosstab between the feature and target with normalize="index"
# 2. Plot a stacked bar chart of the proportions
# 3. Comment on how the target distribution changes across categories

#Categorical Features vs Target
for c in categorical_cols:
  ct = pd.crosstab(df[c], df[target_col], normalize="index")
  print(f"\nProportion of GradeClass within {c}")
  display(ct)

  ct.plot(kind="bar", stacked=True, figsize=(6,4))
  plt.title(f"GradeClass proportion by {c}")
  plt.ylabel("proportion")
  plt.xticks(rotation=0)
  plt.tight_layout()
  plt.show()
# Out:
# Proportion of GradeClass within Gender
# GradeClass       0.0       1.0       2.0       3.0       4.0
# Gender
# 0           0.049573  0.112821  0.168376  0.171795  0.497436
# 1           0.040098  0.112111  0.158756  0.174304  0.514730
# Proportion of GradeClass within Ethnicity
# GradeClass       0.0       1.0       2.0       3.0       4.0
# Ethnicity
# 0           0.038940  0.112676  0.164043  0.160729  0.523612
# 1           0.048682  0.119675  0.160243  0.184584  0.486815
# 2           0.057447  0.100000  0.161702  0.182979  0.497872
# 3           0.040541  0.121622  0.171171  0.193694  0.472973
# Proportion of GradeClass within ParentalEducation
# GradeClass              0.0       1.0       2.0       3.0       4.0
# ParentalEducation
# 0                  0.045267  0.111111  0.172840  0.160494  0.510288
# 1                  0.041209  0.116758  0.174451  0.186813  0.480769
# 2                  0.051392  0.115632  0.167024  0.160600  0.505353
# 3                  0.043597  0.108992  0.144414  0.182561  0.520436
# 4                  0.016667  0.075000  0.108333  0.183333  0.616667
# Proportion of GradeClass within Tutoring
# GradeClass       0.0       1.0       2.0       3.0       4.0
# Tutoring
# 0           0.032914  0.095751  0.163375  0.180132  0.527828
# 1           0.072122  0.151179  0.163662  0.156727  0.456311
# Proportion of GradeClass within ParentalSupport
# GradeClass            0.0       1.0       2.0       3.0       4.0
# ParentalSupport
# 0                0.023585  0.037736  0.174528  0.150943  0.613208
# 1                0.028630  0.079755  0.157464  0.182004  0.552147
# 2                0.021622  0.131081  0.168919  0.164865  0.513514
# 3                0.067432  0.131994  0.160689  0.175036  0.464849
# 4                0.098425  0.129921  0.157480  0.192913  0.421260
# Proportion of GradeClass within Extracurricular
# GradeClass            0.0       1.0       2.0       3.0       4.0
# Extracurricular
# 0                0.035254  0.105763  0.155254  0.179661  0.524068
# 1                0.059978  0.123228  0.176663  0.162486  0.477644
# Proportion of GradeClass within Sports
# GradeClass       0.0       1.0       2.0       3.0       4.0
# Sports
# 0           0.041417  0.106242  0.168667  0.172869  0.510804
# 1           0.052342  0.126722  0.151515  0.173554  0.495868
# Proportion of GradeClass within Music
# GradeClass       0.0       1.0       2.0       3.0       4.0
# Music
# 0           0.044768  0.103592  0.165539  0.173347  0.512754
# 1           0.044586  0.148620  0.154989  0.171975  0.479830
# Proportion of GradeClass within Volunteering
# GradeClass         0.0       1.0       2.0       3.0       4.0
# Volunteering
# 0             0.045635  0.111607  0.165179  0.175595  0.501984
# 1             0.039894  0.117021  0.154255  0.159574  0.529255

# %% [markdown]
# ### Student Notes and Observations
#
# All seem nearly same.

# %% [markdown]
# ## Section 12 — Final Summary and EDA Insights
#
# Summarize your findings from the full EDA process.
#
# **Instructions:**
#
# Write a short summary that answers:
# - Top 3 features that appear most related to the target
# - 1–2 features that seem weak or noisy
# - Any data quality issues you discovered
# - Potential preprocessing steps you would apply in the next module (Module 07)

# %% [markdown]
# ### Student Notes and Observations
#
# Dhoro boitha maro taan
#
# Jongi jabe Pakistan
#
# Lungi Gamcha falaiya
#
# Yunus jabe palaiya
#
# Joy Banglaaaaaaaaaaaaa

# %% [markdown]
# ## Section 13 — Handling Missing Values

# %%
# TODO
# Find Missing Values of your Dataset
# Identify which way you should impute those missing values
# Apply the methods to impute missing values

### NONE

# %% [markdown]
# ## Section 14 — Encoding Categorical Variables

# %%
# TODO
# Identify categorical features
# Take decision on what encoding will you apply for each categorical features
# Apply the methods to encode the features and show final data

### ALRAEDY DONE :)

# %% [markdown]
# ## Section 15 — Normalization and Scaling

# %%
# TODO
# Check if your dataset have features with different range of values or not
# Take decision on whether scaling is required or not
# If required apply one of the scaling method

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Assume df_heart_encoded is our working dataframe with target 'HeartDisease'
target_col = "GradeClass"

X = df.drop(columns=[target_col])
y = df[target_col]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state=42)

# Standard Scaling
scaler_sd = StandardScaler()
X_train_std = scaler_sd.fit_transform(X_train)#mean and SD will be calcualted from X_train
X_test_std = scaler_sd.transform(X_test)

# MinMax Scaling
scaler_mm = MinMaxScaler()
X_train_mm = scaler_mm.fit_transform(X_train)
X_test_mm = scaler_mm.transform(X_test)



print("\n--- Displaying Standard Scaled Data ---")
# Convert scaled arrays back to DataFrame for better visualization with column names
X_train_std_df = pd.DataFrame(X_train_std, columns = X_train.columns, index = X_train.index)
X_test_std_df = pd.DataFrame(X_test_std, columns = X_test.columns, index = X_test.index)
print("\nFirst 5 rows of X_train & X_test (Standard Scaled):")
display(X_train_std_df.head())
display(X_test_std_df.head())


print("\n--- Displaying Standard Scaled Data ---")
# Convert scaled arrays back to DataFrame for better visualization with column names
X_train_mm_df = pd.DataFrame(X_train_mm, columns = X_train.columns, index = X_train.index)
X_test_mm_df = pd.DataFrame(X_test_mm, columns = X_test.columns, index = X_test.index)

print("\nFirst 5 rows of X_train (Minmax Scaled):")
display(X_train_mm_df.head())
display(X_test_mm_df.head())
# Out:
# --- Displaying Standard Scaled Data ---
#
# First 5 rows of X_train & X_test (Standard Scaled):
#       StudentID       Age    Gender  Ethnicity  ParentalEducation  \
# 962   -0.337391 -0.409812 -1.028270  -0.843405           0.234157
# 1053  -0.205119  0.482424  0.972507   0.128380           0.234157
# 1058  -0.197852 -0.409812  0.972507  -0.843405          -1.795205
# 8     -1.724062  0.482424 -1.028270  -0.843405          -1.795205
# 316   -1.276373  0.482424  0.972507  -0.843405           0.234157
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 962          0.184066 -1.605030 -0.653611         0.773247         1.284495
# 1053         0.135451  1.684263 -0.653611        -1.007504         1.284495
# 1058        -1.368727 -1.135131 -0.653611         0.773247         1.284495
# 8           -0.907934 -1.605030 -0.653611        -0.117129        -0.778516
# 316         -0.525948  1.449314 -0.653611         1.663623        -0.778516
#
#         Sports     Music  Volunteering       GPA
# 962  -0.658827  2.009807     -0.426401  1.451143
# 1053 -0.658827 -0.497560     -0.426401 -1.632246
# 1058 -0.658827 -0.497560     -0.426401  1.138752
# 8     1.517850 -0.497560      2.345208  1.093735
# 316  -0.658827 -0.497560     -0.426401 -1.477718
#       StudentID       Age    Gender  Ethnicity  ParentalEducation  \
# 1004  -0.276342 -1.302047  0.972507   1.100164           2.263520
# 196   -1.450797 -0.409812  0.972507  -0.843405           2.263520
# 2342   1.668486 -1.302047 -1.028270  -0.843405          -1.795205
# 1708   0.746945  1.374660  0.972507   0.128380           0.234157
# 435   -1.103403  1.374660 -1.028270  -0.843405          -1.795205
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 1004        -1.685315  0.274566 -0.653611        -0.117129        -0.778516
# 196         -1.359669 -1.722505 -0.653611        -1.007504         1.284495
# 2342         0.150538  0.039617 -0.653611         0.773247        -0.778516
# 1708         1.137569 -1.605030 -0.653611         0.773247         1.284495
# 435         -1.080962  1.449314 -0.653611        -1.007504        -0.778516
#
#         Sports     Music  Volunteering       GPA
# 1004  1.517850  2.009807      2.345208 -0.505423
# 196  -0.658827 -0.497560      2.345208  1.333795
# 2342 -0.658827 -0.497560      2.345208  0.158630
# 1708 -0.658827 -0.497560     -0.426401  1.803133
# 435   1.517850 -0.497560     -0.426401 -1.788528
# --- Displaying Standard Scaled Data ---
#
# First 5 rows of X_train (Minmax Scaled):
#       StudentID       Age  Gender  Ethnicity  ParentalEducation  \
# 962    0.402342  0.333333     0.0   0.000000                0.5
# 1053   0.440402  0.666667     1.0   0.333333                0.5
# 1058   0.442493  0.333333     1.0   0.000000                0.0
# 8      0.003346  0.666667     0.0   0.000000                0.0
# 316    0.132162  0.666667     1.0   0.000000                0.5
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 962          0.539648  0.034483       0.0             0.75              1.0
# 1053         0.525781  1.000000       0.0             0.25              1.0
# 1058         0.096707  0.172414       0.0             0.75              1.0
# 8            0.228151  0.034483       0.0             0.50              0.0
# 316          0.337114  0.931034       0.0             1.00              0.0
#
#       Sports  Music  Volunteering       GPA
# 962      0.0    1.0           0.0  0.806290
# 1053     0.0    0.0           0.0  0.098137
# 1058     0.0    0.0           0.0  0.734544
# 8        1.0    0.0           1.0  0.724205
# 316      0.0    0.0           0.0  0.133627
#       StudentID       Age  Gender  Ethnicity  ParentalEducation  \
# 1004   0.419908  0.000000     1.0   0.666667                1.0
# 196    0.081974  0.333333     1.0   0.000000                1.0
# 2342   0.979506  0.000000     0.0   0.000000                0.0
# 1708   0.714345  1.000000     1.0   0.333333                0.5
# 435    0.181932  1.000000     0.0   0.000000                0.0
#
#       StudyTimeWeekly  Absences  Tutoring  ParentalSupport  Extracurricular  \
# 1004         0.006399  0.586207       0.0             0.50              0.0
# 196          0.099291  0.000000       0.0             0.25              1.0
# 2342         0.530084  0.517241       0.0             0.75              0.0
# 1708         0.811639  0.034483       0.0             0.75              1.0
# 435          0.178794  0.931034       0.0             0.25              0.0
#
#       Sports  Music  Volunteering       GPA
# 1004     1.0    1.0           1.0  0.356931
# 196      0.0    0.0           1.0  0.779339
# 2342     0.0    0.0           1.0  0.509442
# 1708     0.0    0.0           0.0  0.887130
# 435      1.0    0.0           0.0  0.062244
